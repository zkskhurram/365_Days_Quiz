# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; text-align: center; color: white; margin-bottom: 30px;">
#   <h1 style="font-size: 3em; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">🐍 Python Mastery Assessment Review</h1>
#   <p style="font-size: 1.3em; margin: 15px 0;">Python Fundamentals, Tools & Professional Practices | 70 Questions</p>
#   <div style="background: rgba(255,255,255,0.2); padding: 10px 20px; border-radius: 20px; display: inline-block; margin-top: 10px;">
#   </div>
# </div>
#
# > 💡 **Pro Tip**: Use the Table of Contents in Jupyter/Colab to navigate quickly!
#
# ---

# %% [markdown]
# <div style="background: #f8f9fa; border-left: 5px solid #007bff; padding: 15px; margin: 20px 0; border-radius: 5px;">
#   <h3>📊 Notebook Information</h3>
#   <table style="width: 100%; border-collapse: collapse;">
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>🎓 Author:</strong></td><td>Khurram Shahzad</td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>👨‍🏫 Mentor:</strong></td><td>Dr. Aammar Tufail</td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>📧 Email:</strong></td><td><a href="mailto:khurramamq@gmail.com">khurramamq@gmail.com</a></td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>💻 GitHub:</strong></td><td><a href="https://github.com/zkskhurram/Python_-My_Small_knowledge/tree/main" target="_blank">github.com/zkskhurram</a></td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>📚 Topic:</strong></td><td>Python Quiz 1 (Q1–Q70)</td></tr>
#     <tr><td style="padding: 8px;"><strong>🏆 Level:</strong></td><td>Beginner to Advanced</td></tr>
#   </table>
# </div>

# %%
# 🚀 Setup & Imports
import sys
print(f"✅ Python Version: {sys.version}")
print("📦 All required libraries are pre-installed!")
print("🎨 Notebook styling: Custom CSS with gradient themes applied")

# For Kaggle users: This notebook runs perfectly in Kaggle Kernels!

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 25px; border-radius: 15px; color: white; margin: 30px 0;">
#   <h2 style="text-align: center; font-size: 2.5em; margin: 0;">🏆 Performance Dashboard</h2>
#   <div style="display: flex; justify-content: space-around; margin-top: 20px; flex-wrap: wrap;">
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">16/20</div>
#       <div style="font-size: 1.2em;">Basic</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q1–Q20</div>
#     </div>
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">14/20</div>
#       <div style="font-size: 1.2em;">Intermediate</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q21–Q40</div>
#     </div>
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">16/20</div>
#       <div style="font-size: 1.2em;">Advanced</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q41–Q60</div>
#     </div>
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">7/10</div>
#       <div style="font-size: 1.2em;">Expert</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q61–Q70</div>
#     </div>
#   </div>
#   <div style="text-align: center; margin-top: 20px; padding: 15px; background: rgba(255,255,255,0.3); border-radius: 10px;">
#     <span style="font-size: 1.8em; font-weight: bold;">Total Score: 53/70</span>
#     <span style="margin-left: 15px; font-size: 1.3em;">⭐ 76% Accuracy</span>
#     <span style="margin-left: 15px; font-size: 1.1em;">⏱️ 15:34 / 30:00</span>
#   </div>
# </div>
#
# ---

# %% [markdown]
# <div style="background: #fff3cd; border-left: 5px solid #ffc107; padding: 20px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #856404; margin-top: 0;">🎯 Focus Areas for Improvement</h2>
#   <p style="font-size: 1.1em; color: #856404;">Based on your assessment results, prioritize these topics:</p>
#   <ul style="font-size: 1.1em; line-height: 1.8; color: #856404;">
#     <li><strong>Tools & Editors:</strong> GitBash commands, VSCode extensions</li>
#     <li><strong>File Operations:</strong> os.path.exists(), file renaming, .get() method</li>
#     <li><strong>Data Structures:</strong> List.remove() vs pop(), mutable vs immutable</li>
#     <li><strong>Operators:</strong> == vs =, in keyword usage</li>
#     <li><strong>Pandas:</strong> Filtering DataFrames, .loc vs .iloc, merge operations</li>
#     <li><strong>Python Concepts:</strong> try/except blocks, generators with yield</li>
#     <li><strong>Data Science Tools:</strong> Google Colab benefits, broadcasting</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 20px; border-radius: 10px; margin: 30px 0; color: white;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center;">📘 BASIC LEVEL (Q1–Q20)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0;">Foundation Concepts | Essential Python Basics</p>
# </div>
#
# <div style="background: #e7f3ff; border-left: 5px solid #2196F3; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>💡 Study Strategy:</strong> Master these fundamentals before moving to intermediate topics. Each concept builds upon these basics!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #4CAF50; margin-top: 0;">📝 Q1: String Concatenation</h3>
#   <span style="background: #d4edda; padding: 4px 8px; border-radius: 4px; color: #155724; font-weight: bold;">✅ Correct</span>
#
#   **<span style="color: #1976D2;">Question:</span>** What is the result of 'Hello' + 'World'?
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">HelloWorld</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Deep Dive Explanation:</strong><br>
#     The <code>+</code> operator concatenates strings, joining them together <strong>without any separator</strong>.<br><br>
#     <strong>Example:</strong><br>
#     <code>greeting = 'Hello' + ' ' + 'World'  # Adds space explicitly</code><br><br>
#     <strong>⚠️ Tip:</strong> For many strings, use <code>''.join(list_of_strings)</code> for better performance!
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #f44336; margin-top: 0;">📝 Q7: GitBash Definition</h3>
#   <span style="background: #f8d7da; padding: 4px 8px; border-radius: 4px; color: #721c24; font-weight: bold;">❌ Incorrect</span>
#
#   **<span style="color: #1976D2;">Question:</span>** What is GitBash?
#
#   <div style="background: #f8d7da; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>❌ Your Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">A Git GUI tool</code>
#   </div>
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">A command-line interface for Git</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Deep Dive Explanation:</strong><br>
#     GitBash provides a <strong>Bash emulation environment for Windows</strong>, allowing you to use Git commands and Unix-style command-line tools.<br><br>
#     <strong>Key Point:</strong> It's <strong>command-line</strong>, not graphical! GUI tools would be GitKraken, GitHub Desktop, or SourceTree.
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #ffc107; margin-top: 0;">📝 Q35: Dynamic Typing</h3>
#   <span style="background: #fff3cd; padding: 4px 8px; border-radius: 4px; color: #856404; font-weight: bold;">⏭️ Skipped</span>
#
#   **<span style="color: #1976D2;">Question:</span>** What is dynamic typing in Python?
#
#   <div style="background: #fff3cd; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">Variables can change type during execution</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Deep Dive Explanation:</strong><br>
#     Python is <strong>dynamically typed</strong> - a variable can hold an integer, then later be assigned a string. The type is determined at runtime, not in advance.<br><br>
#     <strong>Example:</strong><br>
#     <code>x = 5      # int</code><br>
#     <code>x = "hello"  # Now str (same variable!)</code><br><br>
#     <strong>vs Static Typing:</strong> Languages like Java require declaring types: <code>int x = 5;</code> (cannot change to string)
#   </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%); padding: 20px; border-radius: 10px; margin: 30px 0;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center; color: #2c3e50;">📗 INTERMEDIATE LEVEL (Q21–Q40)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0; color: #34495e;">Data Structures & Control Flow | Core Programming Patterns</p>
# </div>
#
# <div style="background: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>🚀 Ready to Level Up?</strong> These concepts separate beginners from intermediate programmers!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #f44336; margin-top: 0;">📝 Q22: File Existence Check</h3>
#   <span style="background: #f8d7da; padding: 4px 8px; border-radius: 4px; color: #721c24; font-weight: bold;">❌ Incorrect</span>
#
#   **<span style="color: #1976D2;">Question:</span>** How do you check if a file exists in Python?
#
#   <div style="background: #f8d7da; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>❌ Your Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">file.exists()</code>
#   </div>
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">os.path.exists('file.py')</code>
#   </div>
#
#   <div style="background: #ffebee; border-left: 4px solid #f44336; padding: 15px; border-radius: 5px; margin: 15px 0;">
#     <strong>❌ What NOT to do:</strong><br>
#     <code>file.exists()</code> doesn't exist in Python's standard library!
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Correct Usage:</strong><br>
#     <code>import os</code><br>
#     <code>if os.path.exists('my_file.py'):</code><br>
#     <code>&nbsp;&nbsp;&nbsp;&nbsp;print("File found!")</code><br><br>
#     <strong>Related Methods:</strong><br>
#     • <code>os.path.isfile()</code> - Check if it's a file<br>
#     • <code>os.path.isdir()</code> - Check if it's a directory
#   </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 30px 0; color: white;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center;">📕 ADVANCED LEVEL (Q41–Q60)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0;">Functional Programming & OOP | Professional Python Patterns</p>
# </div>
#
# <div style="background: #e1f5fe; border-left: 5px solid #03A9F4; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>🎯 Expert Level:</strong> These concepts are essential for writing efficient, Pythonic code!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #f44336; margin-top: 0;">📝 Q50: DataFrame Filtering</h3>
#   <span style="background: #f8d7da; padding: 4px 8px; border-radius: 4px; color: #721c24; font-weight: bold;">❌ Incorrect</span>
#
#   **<span style="color: #1976D2;">Question:</span>** How do you filter rows where Age > 30 in a DataFrame?
#
#   <div style="background: #f8d7da; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>❌ Your Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">df.filter('Age > 30')</code>
#   </div>
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">df[df['Age'] > 30]</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Boolean Indexing Explained:</strong><br>
#     <code>df['Age'] > 30</code> creates a <strong>boolean mask</strong>: [False, True, True, False, ...]<br><br>
#     <code>df[mask]</code> filters rows where mask is <strong>True</strong><br><br>
#     <strong>Common Mistake:</strong> <code>df.filter()</code> exists but filters <em>columns</em>, not rows!
#   </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 10px; margin: 30px 0; color: white;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center;">🎓 EXPERT LEVEL (Q61–Q70)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0;">Professional Development & Best Practices</p>
# </div>
#
# <div style="background: #fff3cd; border-left: 5px solid #ffc107; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>🔥 Career-Ready:</strong> These concepts prepare you for professional software development!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #f44336; margin-top: 0;">📝 Q65: Google Colab Benefits</h3>
#   <span style="background: #f8d7da; padding: 4px 8px; border-radius: 4px; color: #721c24; font-weight: bold;">❌ Incorrect</span>
#
#   **<span style="color: #1976D2;">Question:</span>** What is a key benefit of Google Colab?
#
#   <div style="background: #f8d7da; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>❌ Your Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">Runs code on local machine</code>
#   </div>
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">Free GPU/TPU access in cloud</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Why Colab is Special:</strong><br>
#     Google Colab provides <strong>free access to powerful GPUs and TPUs</strong> in the cloud!<br><br>
#     <strong>Benefits:</strong><br>
#     • No expensive hardware needed for ML<br>
#     • Runs in browser, nothing to install<br>
#     • Share notebooks like Google Docs<br>
#     • Free tier includes GPU/TPU time
#   </div>
# </div>

# %%
# 🎯 COMPLETE ASSESSMENT REVIEW
# Run this cell to see detailed breakdowns

print("="*70)
print("🐍 PYTHON MASTERY ASSESSMENT - COMPLETE REVIEW")
print("="*70)

# Performance Summary
print("\n📊 PERFORMANCE SUMMARY")
print(f"✅ Correct Answers: 53/70 (76%)")
print(f"❌ Incorrect: 16 questions")
print(f"⏭️  Skipped: 1 question")
print(f"⏱️  Time: 15:34 / 30:00")

# Category Breakdown
print("\n📈 CATEGORY BREAKDOWN")
print("Basic (Q1-20):      16/20 correct - 80% ⭐")
print("Intermediate (21-40): 14/20 correct - 70%")
print("Advanced (41-60):   16/20 correct - 80% ⭐")
print("Expert (61-70):      7/10 correct - 70%")

# Focus Areas
print("\n🎯 FOCUS AREAS FOR IMPROVEMENT")
focus_areas = [
    "GitBash commands (Q7, Q26, Q37)",
    "File operations (Q22, Q57)",
    "DataFrames & Pandas (Q43, Q50, Q54, Q55, Q67)",
    "Operators & Syntax (Q27, Q40, Q56, Q58)",
    "Python tools (Q12, Q69, Q65)",
    "List methods (Q23, Q25)",
    "Error handling (Q29, Q56)"
]
for i, area in enumerate(focus_areas, 1):
    print(f"   {i}. {area}")

print("\n" + "="*70)
print("✅ Review Complete! Ready to tackle your weak spots?")
print("="*70)

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; margin: 30px 0;">
#   <h1 style="text-align: center; font-size: 2.5em; margin: 0;">🎓 Study Summary & Next Steps</h1>
#
#   <div style="background: rgba(255,255,255,0.1); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: #fff;">📊 Your Progress</h2>
#     <p style="font-size: 1.1em;">✅ <strong>53/70 (76%)</strong> - Strong Understanding! You're well on your way to mastery.</p>
#
#    <h3 style="color: #fff; margin-top: 20px;">🔥 Topics to Review:</h3>
# <ul style="line-height: 1.8; font-size: 1.1em;">
#   <li>🛠️ <strong>Tools:</strong> Git Bash commands (mv, cd), <code>os.path.exists()</code></li>
#   <li>📊 <strong>Pandas:</strong> Boolean indexing, <code>.loc</code>/<code>.iloc</code>, <code>df[condition]</code></li>
#   <li>🐍 <strong>Python Methods:</strong> <code>list.remove()</code> vs <code>pop()</code>, <code>dict.get()</code></li>
#   <li>⚙️ <strong>Concepts:</strong> <code>try</code>/<code>except</code>, generators (<code>yield</code>), dynamic typing</li>
#   <li>💻 <strong>Editors:</strong> VS Code extensions, GitHub Student Developer Pack benefits</li>
# </ul>
#
# </div>
#
#
#   <div style="background: rgba(255,255,255,0.1); padding: 20px; border-radius: 10px;">
#     <h2 style="color: #fff;">🚀 Next Steps:</h2>
#     <ol style="line-height: 1.8; font-size: 1.1em;">
#       <li><strong>Review Mistakes:</strong> Focus on the 16 incorrect questions</li>
#       <li><strong>Hands-On Practice:</strong> Code each concept in Jupyter</li>
#       <li><strong>Build Projects:</strong> Apply tools in real-world scenarios</li>
#       <li><strong>GitBash Mastery:</strong> Practice Unix commands daily</li>
#       <li><strong>Retake Assessment:</strong> Target 90%+ in 1 week</li>
#       <li><strong>Kaggle Competitions:</strong> Apply Pandas & NumPy skills</li>
#     </ol>
#   </div>
# </div>
#
# <div style="background: #d4edda; border-left: 5px solid #28a745; padding: 20px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #155724; margin-top: 0;">🎯 Ready for More?</h2>
#   <p style="color: #155724;">This notebook is ready for Kaggle upload! It includes:</p>
#   <ul style="line-height: 1.8; color: #155724;">
#     <li>✨ Beautiful gradient themes and professional styling</li>
#     <li>📱 Mobile-responsive design</li>
#     <li>📊 Detailed performance dashboard</li>
#     <li>🎯 70 questions with detailed explanations</li>
#     <li>💡 Color-coded correct/incorrect/skipped status</li>
#     <li>🔥 Focus areas for targeted improvement</li>
#   </ul>
# </div>

# %% [markdown]
# ---
#
# <div style="background: #1e1e1e; color: white; padding: 20px; border-radius: 10px; text-align: center; margin: 30px 0;">
#   <h2 style="margin: 0; color: #ffd700;">🏆 Thank You for Learning with Us!</h2>
#   <p style="font-size: 1.1em; margin: 10px 0;">Keep coding, keep growing! 🚀</p>
#
#   <div style="display: flex; justify-content: center; gap: 20px; flex-wrap: wrap; margin-top: 15px;">
#     <a href="mailto:khurramamq@gmail.com" style="background: #007bff; color: white; padding: 10px 20px; border-radius: 5px; text-decoration: none;">📧 Email</a>
#     <a href="https://github.com/zkskhurram" style="background: #333; color: white; padding: 10px 20px; border-radius: 5px; text-decoration: none;">💻 GitHub</a>
#     <a href="https://www.kaggle.com/" style="background: #20beff; color: white; padding: 10px 20px; border-radius: 5px; text-decoration: none;">🎯 Kaggle</a>
#   </div>
#
#   <p style="margin-top: 20px; font-size: 0.9em; opacity: 0.8;">
#     📅 Created: 29-DEC-2025 | Day 10 of 365 Days Plan<br>
#     🎓 Mentor: Dr. Aammar Tufail | Author: Khurram Shahzad
#
#    🎓 Score: 53/70 (76%) | Time: 15:34 / 30:00
#   </p>
# </div>
#
# <div style="text-align: center; margin: 20px 0;">
#   <p style="font-size: 1.2em; color: #666;">
#     Made with ❤️ for the Python community
#   </p>
#   <p style="font-size: 1em; color: #999;">
#     Keep coding, keep growing! 🐍✨
#   </p>
# </div>
