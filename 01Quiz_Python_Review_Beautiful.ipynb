# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; text-align: center; color: white; margin-bottom: 30px;">
#   <h1 style="font-size: 3em; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">🐍 Python Mastery Quiz Review</h1>
#   <p style="font-size: 1.3em; margin: 15px 0;">Q1–Q30 | Comprehensive Solutions & Explanations</p>
#   <div style="background: rgba(255,255,255,0.2); padding: 10px 20px; border-radius: 20px; display: inline-block; margin-top: 10px;">
#     <strong>📅 27-DEC-2025 | Day 08 of 365 Days Plan</strong>
#   </div>
# </div>
#
# > 💡 **Pro Tip**: Use the Table of Contents in Jupyter/Colab to navigate quickly!
#
# ---

# %% [markdown]
# <div style="background: #f8f9fa; border-left: 5px solid #007bff; padding: 15px; margin: 20px 0; border-radius: 5px;">
#   <h3>📊 Notebook Information</h3>
#   <table style="width: 100%; border-collapse: collapse;">
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>🎓 Author:</strong></td><td>Khurram Shahzad</td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>👨‍🏫 Mentor:</strong></td><td>Dr. Aammar Tufail</td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>📧 Email:</strong></td><td><a href="mailto:khurramamq@gmail.com">khurramamq@gmail.com</a></td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>💻 GitHub:</strong></td><td><a href="https://github.com/zkskhurram/Python_-My_Small_knowledge/tree/main" target="_blank">github.com/zkskhurram</a></td></tr>
#     <tr><td style="padding: 8px; border-bottom: 1px solid #dee2e6;"><strong>📚 Topic:</strong></td><td>Python Quiz 1 (Q1–Q30)</td></tr>
#     <tr><td style="padding: 8px;"><strong>🏆 Level:</strong></td><td>Beginner to Advanced</td></tr>
#   </table>
# </div>

# %%
# 🚀 Setup & Imports
import sys
print(f"✅ Python Version: {sys.version}")
print("📦 All required libraries are pre-installed!")
print("🎨 Notebook styling: Custom CSS with gradient themes applied")

# For Kaggle users: This notebook runs perfectly in Kaggle Kernels!

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 25px; border-radius: 15px; color: white; margin: 30px 0;">
#   <h2 style="text-align: center; font-size: 2.5em; margin: 0;">🏆 Performance Dashboard</h2>
#   <div style="display: flex; justify-content: space-around; margin-top: 20px; flex-wrap: wrap;">
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">8/10</div>
#       <div style="font-size: 1.2em;">Basic</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q1–Q10</div>
#     </div>
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">7/10</div>
#       <div style="font-size: 1.2em;">Intermediate</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q11–Q20</div>
#     </div>
#     <div style="text-align: center; background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; margin: 10px;">
#       <div style="font-size: 3em; font-weight: bold;">7/10</div>
#       <div style="font-size: 1.2em;">Advanced</div>
#       <div style="font-size: 0.9em; opacity: 0.9;">Q21–Q30</div>
#     </div>
#   </div>
#   <div style="text-align: center; margin-top: 20px; padding: 15px; background: rgba(255,255,255,0.3); border-radius: 10px;">
#     <span style="font-size: 1.8em; font-weight: bold;">Total Score: 22/30</span>
#     <span style="margin-left: 15px; font-size: 1.3em;">⭐ 73.3% Accuracy</span>
#   </div>
# </div>
#
# ---

# %% [markdown]
# <div style="background: #fff3cd; border-left: 5px solid #ffc107; padding: 20px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #856404; margin-top: 0;">🎯 Focus Areas for Improvement</h2>
#   <p style="font-size: 1.1em; color: #856404;">Based on your quiz results, prioritize these topics:</p>
#   <ul style="font-size: 1.1em; line-height: 1.8; color: #856404;">
#     <li><code style="background: #fff; padding: 2px 6px; border-radius: 3px;">=</code> vs <code style="background: #fff; padding: 2px 6px; border-radius: 3px;">==</code> (Assignment vs Comparison)</li>
#     <li><code style="background: #fff; padding: 2px 6px; border-radius: 3px;">%</code> Modulo Operator (Remainder calculation)</li>
#     <li><code style="background: #fff; padding: 2px 6px; border-radius: 3px;">*</code> String Repetition</li>
#     <li><code style="background: #fff; padding: 2px 6px; border-radius: 3px;">in</code> Keyword (Membership testing)</li>
#     <li><code style="background: #fff; padding: 2px 6px; border-radius: 3px;">map()</code>, <code style="background: #fff; padding: 2px 6px; border-radius: 3px;">filter()</code> Functions</li>
#     <li><code style="background: #fff; padding: 2px 6px; border-radius: 3px;">dict.get()</code> Method with default values</li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 20px; border-radius: 10px; margin: 30px 0; color: white;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center;">📘 BASIC LEVEL (Q1–Q10)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0;">Foundation Concepts | Essential Python Basics</p>
# </div>
#
# <div style="background: #e7f3ff; border-left: 5px solid #2196F3; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>💡 Study Strategy:</strong> Master these fundamentals before moving to intermediate topics. Each concept builds upon these basics!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #4CAF50; margin-top: 0;">📝 Q1: Variable Assignment Operator</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** Which symbol is used to assign a value to a variable?
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px; font-size: 1.2em;">=</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Deep Dive Explanation:</strong><br>
#     The single equals sign <code>=</code> is the <strong>assignment operator</strong> in Python. It stores the value on the right into the variable on the left.<br><br>
#     <strong>Example:</strong><br>
#     <code>x = 5</code>  # Creates variable 'x' and stores value 5<br><br>
#     <strong>⚠️ Common Mistake:</strong> Don't confuse with <code>==</code> which is for comparison!<br>
#     <code>x == 5</code>  # Checks if x equals 5 (returns True/False)
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #4CAF50; margin-top: 0;">📝 Q2: Boolean Data Type</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** Which data type stores True or False?
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">Boolean</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Deep Dive Explanation:</strong><br>
#     Boolean is a fundamental data type named after George Boole. It's crucial for:<br>
#     • Conditional statements (if/else)<br>
#     • Loop control<br>
#     • Logical operations<br><br>
#     <strong>Fun Fact:</strong> In Python, <code>True</code> and <code>False</code> are capitalized and are instances of <code>bool</code> class!
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #4CAF50; margin-top: 0;">📝 Q3: Python File Extension</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** What is the file extension for Python files?
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">.py</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Deep Dive Explanation:</strong><br>
#     <strong>Common Python Extensions:</strong><br>
#     • <code>.py</code> - Standard Python source code<br>
#     • <code>.pyc</code> - Compiled bytecode (created automatically)<br>
#     • <code>.pyw</code> - Python script for Windows GUI<br>
#     • <code>.ipynb</code> - Jupyter Notebook files<br><br>
#     <strong>Best Practice:</strong> Always name your files descriptively: <code>data_analysis.py</code> not <code>test.py</code>!
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #4CAF50; margin-top: 0;">📝 Q10: Conditional Logic</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** If `age = 15`, what will this code print?
#
#   ```python
#   if age >= 18:
#       print("Adult")
#   else:
#       print("Not adult")
#   ```
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">Not adult</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Flow Analysis:</strong><br>
#     <code>age = 15</code><br>
#     ↓ Check: <code>15 >= 18</code> → <strong>False</strong><br>
#     ↓ Skip <code>if</code> block<br>
#     ↓ Execute <code>else</code> block<br>
#     ↓ <strong>Output:</strong> "Not adult"<br><br>
#     <strong>Key Insight:</strong> The <code>else</code> block runs ONLY when the <code>if</code> condition is False!
#   </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%); padding: 20px; border-radius: 10px; margin: 30px 0;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center; color: #2c3e50;">📗 INTERMEDIATE LEVEL (Q11–Q20)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0; color: #34495e;">Data Structures & Control Flow | Core Programming Patterns</p>
# </div>
#
# <div style="background: #e8f5e9; border-left: 5px solid #4CAF50; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>🚀 Ready to Level Up?</strong> These concepts separate beginners from intermediate programmers!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #FF9800; margin-top: 0;">📝 Q12: Modulo Operator</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** What does `num % 2` mean?
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <em>Remainder after dividing `num` by 2</em>
#   </div>
#
#   <div style="background: #fff3cd; border-left: 4px solid #ffc107; padding: 15px; border-radius: 5px; margin: 15px 0;">
#     <strong>🎯 Pro Tip:</strong> This is THE way to check even/odd numbers!<br>
#     <code>if num % 2 == 0:  # Even number!</code><br>
#     <code>&nbsp;&nbsp;&nbsp;&nbsp;print("Even")<br>else:<br>&nbsp;&nbsp;&nbsp;&nbsp;print("Odd")</code>
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Modulo Magic:</strong><table style="width: 100%; margin-top: 10px; border-collapse: collapse;"><tr style="background: #e3f2fd;"><th style="padding: 8px; border: 1px solid #ccc;">Expression</th><th style="padding: 8px; border: 1px solid #ccc;">Result</th><th style="padding: 8px; border: 1px solid #ccc;">Use Case</th></tr><tr><td style="padding: 8px; border: 1px solid #ccc;"><code>10 % 3</code></td><td style="padding: 8px; border: 1px solid #ccc;"><code>1</code></td><td style="padding: 8px; border: 1px solid #ccc;">Remaining after division</td></tr><tr><td style="padding: 8px; border: 1px solid #ccc;"><code>7 % 2</code></td><td style="padding: 8px; border: 1px solid #ccc;"><code>1</code></td><td style="padding: 8px; border: 1px solid #ccc;">Odd number check</td></tr><tr><td style="padding: 8px; border: 1px solid #ccc;"><code>8 % 4</code></td><td style="padding: 8px; border: 1px solid #ccc;"><code>0</code></td><td style="padding: 8px; border: 1px solid #ccc;">Divisibility test</td></tr><tr><td style="padding: 8px; border: 1px solid #ccc;"><code>15 % 5</code></td><td style="padding: 8px; border: 1px solid #ccc;"><code>0</code></td><td style="padding: 8px; border: 1px solid #ccc;">Multiple verification</td></tr></table>
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #FF9800; margin-top: 0;">📝 Q17: String Repetition</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** What is the output?
#
#   ```python
#   x = 'abc'
#   print(x * 3)
#   ```
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">abcabcabc</code>
#   </div>
#
#   <div style="background: #e8f5e9; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>🎮 Interactive Demo:</strong>
# ```python
# # Try these in your mind first!
# print('Hi' * 4)      # Output: HiHiHiHi
# print('=' * 20)      # Output: ====================
# print('❤️' * 5)      # Output: ❤️❤️❤️❤️❤️
# print('Error! ' * 3) # Output: Error! Error! Error!
# ```
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Creative Uses:</strong><br>
#     • Creating borders: <code>'=' * 50</code><br>
#     • Generating patterns: <code>'*' * i</code> in loops<br>
#     • String padding and formatting<br>
#     • Repeating error messages or warnings
#   </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 30px 0; color: white;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center;">📕 ADVANCED LEVEL (Q21–Q30)</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0;">Functional Programming & OOP | Professional Python Patterns</p>
# </div>
#
# <div style="background: #e1f5fe; border-left: 5px solid #03A9F4; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>🎯 Expert Level:</strong> These concepts are essential for writing efficient, Pythonic code!
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #9C27B0; margin-top: 0;">📝 Q22: Dictionary Get Method</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** What will print?
#
#   ```python
#   d = {'a': 1, 'b': 2}
#   print(d.get('c', 0))
#   ```
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">0</code>
#   </div>
#
#   <div style="background: #ffebee; border-left: 4px solid #f44336; padding: 15px; border-radius: 5px; margin: 15px 0;">
#     <strong>❌ What NOT to do:</strong><br>
#     <code>print(d['c'])  # KeyError: 'c'</code><br><br>
#     This raises an error if key doesn't exist!
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Safe Dictionary Access:</strong><br>
#     <code>dict.get(key, default)</code> is the SAFE way to access dictionaries!<br><br>
#     <strong>Pattern:</strong><br>
#     <code>value = d.get('key', 'default_value')</code><br><br>
#     <strong>Best Practice:</strong> Always use <code>.get()</code> when you're not sure if the key exists!
#   </div>
# </div>

# %% [markdown]
# <div style="border: 2px solid #e0e0e0; border-radius: 10px; padding: 20px; margin: 20px 0; background: #fafafa;">
#   <h3 style="color: #9C27B0; margin-top: 0;">📝 Q25: Recursion - Factorial</h3>
#
#   **<span style="color: #1976D2;">Question:</span>** What will this code output?
#
#   ```python
#   def factorial(n):
#       if n <= 1:
#           return 1
#       return n * factorial(n-1)
#
#   print(factorial(4))
#   ```
#
#   <div style="background: #d4edda; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>✅ Correct Answer:</strong> <code style="background: #fff; padding: 3px 8px; border-radius: 3px;">24</code>
#   </div>
#
#   <div style="background: #f3e5f5; border-radius: 5px; padding: 10px; margin: 15px 0;">
#     <strong>🔄 Recursion Stack Visualization:</strong><br>
#     <code>factorial(4)</code><br>
#     → <code>4 * factorial(3)</code><br>
#     &nbsp;&nbsp;→ <code>3 * factorial(2)</code><br>
#     &nbsp;&nbsp;&nbsp;&nbsp;→ <code>2 * factorial(1)</code><br>
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;→ <code>1</code> (base case reached!)<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;→ <code>2 * 1 = 2</code><br>
#     &nbsp;&nbsp;→ <code>3 * 2 = 6</code><br>
#     → <code>4 * 6 = 24</code> ← Final Result!
#   </div>
#
#   <div style="background: #f0f8ff; border-left: 4px solid #2196F3; padding: 15px; border-radius: 5px;">
#     <strong>💡 Pythonic Alternative:</strong><br>
#     <code>import math<br>print(math.factorial(4))  # 24</code><br><br>
#     <strong>When to Use Recursion:</strong><br>
#     • Tree traversals<br>
#     • Divide and conquer algorithms<br>
#     • Mathematical sequences (Fibonacci)<br>
#     • Backtracking problems
#   </div>
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #fa709a 0%, #fee140 100%); padding: 20px; border-radius: 10px; margin: 30px 0; color: white;">
#   <h1 style="margin: 0; font-size: 2.5em; text-align: center;">🧪 HANDS-ON PRACTICE</h1>
#   <p style="text-align: center; font-size: 1.2em; margin: 10px 0;">Strengthen Your Skills | Interactive Coding Challenges</p>
# </div>
#
# <div style="background: #fff3cd; border-left: 5px solid #ffc107; padding: 15px; margin: 15px 0; border-radius: 5px;">
#   <strong>⚡ Challenge Yourself!</strong> Try these before looking at the solutions below.
# </div>
#
# <div style="background: #e7f3ff; border-radius: 10px; padding: 20px; margin: 20px 0;">
#   <h3 style="color: #1976D2;">Practice Problems:</h3>
#   <ol style="font-size: 1.1em; line-height: 2;">
#     <li><strong>Operator Distinction:</strong> What's the difference between <code>=</code> and <code>==</code>?</li>
#     <li><strong>Modulo Magic:</strong> What is <code>9 % 4</code>?</li>
#     <li><strong>String Multiplication:</strong> What is the output of <code>'hi' * 4</code>?</li>
#     <li><strong>Membership Test:</strong> What does <code>'x' in ['a','x','b']</code> return?</li>
#     <li><strong>Map to List:</strong> Convert: <code>map(lambda x: x*2, [1,2,3])</code> into a list.</li>
#   </ol>
# </div>

# %%
# 🎯 PRACTICE SOLUTIONS
# Run this cell to see the answers and detailed explanations

print("="*60)
print("🎯 PRACTICE SOLUTIONS")
print("="*60)

# 1) '=' vs '=='
print("\n1️⃣ '=' vs '=='")
x = 5  # Assignment: puts 5 in variable x
print(f"   x = 5 (Assignment)")
print(f"   x == 5 → {x == 5} (Comparison)")
print("   💡 = stores value, == checks equality")

# 2) Modulo
print("\n2️⃣ 9 % 4")
result = 9 % 4
print(f"   9 ÷ 4 = 2 with remainder {result}")
print(f"   9 % 4 = {result}")
print("   💡 4*2=8, 9-8=1 (remainder)")

# 3) String repetition
print("\n3️⃣ 'hi' * 4")
result = 'hi' * 4
print(f"   'hi' * 4 = '{result}'")
print("   💡 String multiplication = repetition")

# 4) Membership
print("\n4️⃣ 'x' in ['a','x','b']")
result = 'x' in ['a','x','b']
print(f"   'x' in ['a','x','b'] → {result}")
print("   💡 'x' is one of the items in the list")

# 5) Convert map to list
print("\n5️⃣ map(lambda x: x*2, [1,2,3])")
result = list(map(lambda x: x*2, [1,2,3]))
print(f"   list(map(lambda x: x*2, [1,2,3])) = {result}")
print("   💡 map applies function to each item")

print("\n" + "="*60)
print("✅ Practice Complete! How did you do?")
print("="*60)

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; margin: 30px 0;">
#   <h1 style="text-align: center; font-size: 2.5em; margin: 0;">🎓 Study Summary & Next Steps</h1>
#
#   <div style="background: rgba(255,255,255,0.1); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: #fff;">📊 Your Progress</h2>
#     <p style="font-size: 1.1em;">✅ <strong>22/30 (73.3%)</strong> - Great foundation! You're on track to mastery.</p>
#
#     <h3 style="color: #fff; margin-top: 20px;">🔥 Topics to Review:</h3>
#     <ul style="line-height: 1.8; font-size: 1.1em;">
#       <li>✍️ Assignment (<code>=</code>) vs Comparison (<code>==</code>)</li>
#       <li>🧮 Modulo operator for remainder calculations</li>
#       <li>🔁 String repetition with <code>*</code></li>
#       <li>🔍 Membership testing with <code>in</code></li>
#       <li>⚙️ Functional programming: <code>map()</code> & <code>filter()</code></li>
#       <li>📖 Dictionary <code>.get()</code> method for safe access</li>
#     </ul>
#   </div>
#
#   <div style="background: rgba(255,255,255,0.1); padding: 20px; border-radius: 10px;">
#     <h2 style="color: #fff;">🚀 Next Steps:</h2>
#     <ol style="line-height: 1.8; font-size: 1.1em;">
#       <li><strong>Review Mistakes:</strong> Focus on questions you got wrong</li>
#       <li><strong>Practice Daily:</strong> Code for 30 minutes every day</li>
#       <li><strong>Build Projects:</strong> Apply concepts in mini-projects</li>
#       <li><strong>Join Community:</strong> Participate in Kaggle competitions</li>
#       <li><strong>Track Progress:</strong> Retake quiz in 1 week</li>
#     </ol>
#   </div>
# </div>
#
# <div style="background: #d4edda; border-left: 5px solid #28a745; padding: 20px; margin: 20px 0; border-radius: 5px;">
#   <h2 style="color: #155724; margin-top: 0;">🎯 Ready for More?</h2>
#   <p style="color: #155724;">This notebook is ready for Kaggle upload! It includes:</p>
#   <ul style="line-height: 1.8; color: #155724;">
#     <li>✨ Beautiful gradient themes and professional styling</li>
#     <li>📱 Mobile-responsive design</li>
#     <li>💡 Detailed explanations with examples</li>
#     <li>🎮 Interactive practice exercises</li>
#     <li>📊 Progress tracking dashboard</li>
#     <li>🔥 Kaggle-optimized formatting</li>
#   </ul>
# </div>

# %% [markdown]
# ---
#
# <div style="background: #1e1e1e; color: white; padding: 20px; border-radius: 10px; text-align: center; margin: 30px 0;">
#   <h2 style="margin: 0; color: #ffd700;">🏆 Thank You for Learning with Us!</h2>
#   <p style="font-size: 1.1em; margin: 10px 0;">Keep coding, keep growing! 🚀</p>
#
#   <div style="display: flex; justify-content: center; gap: 20px; flex-wrap: wrap; margin-top: 15px;">
#     <a href="mailto:khurramamq@gmail.com" style="background: #007bff; color: white; padding: 10px 20px; border-radius: 5px; text-decoration: none;">📧 Email</a>
#     <a href="https://github.com/zkskhurram" style="background: #333; color: white; padding: 10px 20px; border-radius: 5px; text-decoration: none;">💻 GitHub</a>
#     <a href="https://www.kaggle.com/" style="background: #20beff; color: white; padding: 10px 20px; border-radius: 5px; text-decoration: none;">🎯 Kaggle</a>
#   </div>
#
#   <p style="margin-top: 20px; font-size: 0.9em; opacity: 0.8;">
#     📅 Created: 27-DEC-2025 | Day 08 of 365 Days Plan<br>
#     🎓 Mentor: Dr. Aammar Tufail | Author: Khurram Shahzad
#   </p>
# </div>
#
# <div style="text-align: center; margin: 20px 0;">
#   <p style="font-size: 1.2em; color: #666;">
#     Made with ❤️ for the Python community
#   </p>
#   <p style="font-size: 1em; color: #999;">
#     Happy Coding! 🐍✨
#   </p>
# </div>
